# %%
import torch
from torch import nn
import torchvision
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

import random

import numpy as np

import matplotlib.cm as cm

import pickle

import os, sys

from denoising_assessment_project.utils import metric_compute, stats_compute, stats_plot

# parameters setup 
from denoising_assessment_project.global_vars import global_vars

# %matplotlib notebook

import os

# %%
global_vars.init()

# %%
# -PARAMETERS FOR GENERATION-

# image dimensions
global_vars.image_dimensions = torch.Size([256,256])

# reps in a series ????
global_vars.series_size = 20

# we want: 
# a spectrum of images 1-50 blobs (50 stacks?) where each image in the series stems from the previous one + 1  
# how do we want to vary the signal? (in the range of 10-1000?), or do this one just for a single signal value?
# how many repetitions per each stack of blob number-signal value (peak value) combination? (previously there were 50)

global_vars.blobs_population_sizes = torch.arange(0,51)
global_vars.peak_values = torch.arange(10,210,10)

# %%
distinct_blob_quantities_tensor = data_gen_t2.varying_blob_quantities_img_series_generate(global_vars.series_size, global_vars.blobs_population_sizes, global_vars.image_dimensions)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-ecba9d8ea5b0> in <module>
# ----> 1 distinct_blob_quantities_tensor = functions.varying_blob_quantities_img_series_generate_plus_one(global_vars.series_size, global_vars.blobs_population_sizes, global_vars.image_dimensions)
#
# ~/Desktop/denoising_assessment/denoising_assessment_project/utils/functions.py in varying_blob_quantities_img_series_generate_plus_one(series_size, my_range, image_dimensions)
#     106
#     107             # append a single image
# --> 108             distinct_blob_quantities[i,idx,:,:] = image
#     109
#     110     return distinct_blob_quantities
#
# IndexError: index 50 is out of bounds for dimension 1 with size 50

# %%
print(type(global_vars.series_size))
# Out:
# <class 'int'>

# %%
print(distinct_blob_quantities_tensor[0,:,:,:].shape)
print(distinct_blob_quantities_tensor[49,:,:,:].shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-4b39362c0d07> in <module>
# ----> 1 print(distinct_blob_quantities_tensor[0,:,:,:].shape)
#       2 print(distinct_blob_quantities_tensor[49,:,:,:].shape)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
b = distinct_blob_quantities_tensor[1]

# %%
distinct_blob_quantities_tensor[1].shape
# Out:
# torch.Size([20, 50, 256, 256])

# %%
# TODO:
# -> the first one should have 0 blobs //
# -> check the results for more randomized series //
# -> tidy the code up 
# -> generate the images 

for i in range(10):
    image = b[2,i,:,:]
    
    fig = plt.figure()
    plt.clf()
    plt.imshow(image.cpu())
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
a = torch.zeros(*global_vars.image_dimensions,2)

# %%
a.shape
# Out:
# torch.Size([256, 256, 2])
