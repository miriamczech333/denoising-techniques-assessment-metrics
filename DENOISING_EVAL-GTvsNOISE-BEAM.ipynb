# %%
import torch
from torch import nn
import torchvision
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

import random

import numpy as np

import matplotlib.cm as cm

import pickle

from utils import functions

# parameters setup 
from global_vars import global_vars

# %matplotlib notebook

# %%
# restoring variables from memory (GT images, indices)
# %store -r

# %%
# opening GT images and noised images
with open('pickled_data/EVAL/un_noised_images_eval_beam.pkl', 'rb') as un_noised_images_eval_beam_pickled:
    un_noised_images = pickle.load(un_noised_images_eval_beam_pickled)
with open('pickled_data/EVAL/noised_images_eval_beam.pkl', 'rb') as noised_images_eval_beam_pickled:
    noised_images = pickle.load(noised_images_eval_beam_pickled)

# %%
# to be deleted
# 2nd 2D plot:

# -> noise, purple one 
print('noise, purple one: ', values[1,19])
# -> noise, red one 
print('noise, red one: ', values[18,19])

print('')

# -> CARE, purple one 
print('CARE, purple one: ', values_CARE[1,19])
# -> CARE, red one 
print('CARE, red one: ', values_CARE[18,19])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7e0433d4311b> in <module>
#       3
#       4 # -> noise, purple one
# ----> 5 print('noise, purple one: ', values[1,19])
#       6 # -> noise, red one
#       7 print('noise, red one: ', values[18,19])
#
# NameError: name 'values' is not defined

# %%
# -NRMSE-
# 4a. Computing NRMSE for each GT-NOISE image pair in the data collection
# dims=[m, n, reps]
metric_output = functions.NRMSE_compute(un_noised_images, noised_images)

# 5. Computing statistics for the metric across all n x m sets 
# dims=[m, n, 2]
metric_stats_NRMSE_beam = functions.set_mean_std_compute(metric_output)

# %%
# -RMSE-
# 4b. Computing RMSE for each image in the data collection
# dims=[m, n, reps]
metric_output = functions.RMSE_compute(un_noised_images, noised_images)
#tests 
print(metric_output.shape)

# 5. Computing statistics for the metric across all n x m sets 
# dims=[m, n, 2]
metric_stats_RMSE_beam = functions.set_mean_std_compute(metric_output)
# Out:
# torch.Size([20, 20, 50])

# %%
# -PSNR-
# 4c. Computing PSNR for each image in the data collection
# dims=[m, n, reps]
metric_output = functions.PSNR_compute(un_noised_images, noised_images)
#tests 
print(metric_output.shape)

# 5. Computing statistics for the metric across all n x m sets 
# dims=[m, n, 2]
metric_stats_PSNR_beam = functions.set_mean_std_compute(metric_output)
# Out:
# torch.Size([20, 20, 50])

# %%
# -SSIM-
# 4c. Computing SSIM for each image in the data collection
# dims=[m, n, reps]
metric_output = functions.SSIM_compute(un_noised_images, noised_images)
#tests 
print(metric_output.shape)

# 5. Computing statistics for the metric across all n x m sets 
# dims=[m, n, 2]
metric_stats_SSIM_beam = functions.set_mean_std_compute(metric_output)
# Out:
# torch.Size([20, 20, 50])

# %%
# -MS_SSIM-
# 4c. Computing MS_SSIM for each image in the data collection
# dims=[m, n, reps]
metric_output = functions.MS_SSIM_compute(un_noised_images, noised_images)
#tests 
print(metric_output.shape)

# 5. Computing statistics for the metric across all n x m sets 
# dims=[m, n, 2]
metric_stats_MS_SSIM_beam = functions.set_mean_std_compute(metric_output)
# Out:
# torch.Size([20, 20, 50])

# %%
# %store metric_stats_NRMSE_beam
# %store metric_stats_RMSE_beam
# %store metric_stats_PSNR_beam
# %store metric_stats_SSIM_beam
# %store metric_stats_MS_SSIM_beam
# Out:
# Stored 'metric_stats_NRMSE_beam' (Tensor)
# Stored 'metric_stats_RMSE_beam' (Tensor)
# Stored 'metric_stats_PSNR_beam' (Tensor)
# Stored 'metric_stats_SSIM_beam' (Tensor)
# Stored 'metric_stats_MS_SSIM_beam' (Tensor)

# %%
# -NRMSE-
# 6. plotting obtained stats
functions.plot_stats(metric_stats_NRMSE_beam, indices, 'NRMSE')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# -RMSE-
# 6. plotting obtained stats
functions.plot_stats(metric_stats_RMSE_beam, indices, 'RMSE')
# Out:
# <div id='de5f3a90-3d76-4913-be66-4587a95f6313'></div>
# <div id='e15528fa-d294-4e5e-b7d8-6889c7a4cc7b'></div>
# <div id='4c4b54c3-57a4-44d5-9bde-a09497308fde'></div>

# %%
# -PSNR-
# 6. plotting obtained stats
functions.plot_stats(metric_stats_PSNR_beam, indices, 'PSNR')
# Out:
# <div id='87ba4027-0719-4192-a5e3-747ea2b22076'></div>
# <div id='29666e90-a787-49ae-8fca-6baffb20234b'></div>
# <div id='58501d0e-b1e8-4db0-9035-c4f12d24ad43'></div>

# %%
# -SSIM-
# 6. plotting obtained stats
functions.plot_stats(metric_stats_SSIM_beam, indices, 'SSIM')
# Out:
# <div id='c468367a-40d9-4931-9399-9a3f96f4f07d'></div>
# <div id='1def62e1-2f0e-471c-8336-6f26e6e80954'></div>
# <div id='8d044d52-f57a-4a4a-954f-d70019c58907'></div>

# %%
# -MS_SSIM-
# 6. plotting obtained stats
functions.plot_stats(metric_stats_MS_SSIM_beam, indices, 'MS_SSIM')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
